# %%
import gym
from gym import spaces
import numpy as np
import random
from collections import Counter

# %%
WHITE = 1
BLACK = -1
EMPTY = 0

class ASCII:
  WHITE = '⚪'
  BLACK = '⚫'
  EMPTY = '🟩'

  @classmethod
  def getsymbol(self, value):
    return self.WHITE if value == WHITE else self.BLACK if value == BLACK else self.EMPTY

# Increments to use depending on the direction to search the grid
direction2row = {1:-1, 2:-1, 3:0, 4:1, 5:1, 6:1, 7:0, 8:-1}
direction2col = {1:0, 2:1, 3:1, 4:1, 5:0, 6:-1, 7:-1, 8:-1}

class OthelloEnv(gym.Env):
    def __init__(self, n=8):
        
        self.done = False
        self.turn_passed = False # True when a player passes turn because no valid moves
        self.observation_space = spaces.Box(low = -1, high = 1, shape = (n, n), dtype = int)
        self.action_space = spaces.Discrete(n*n)
        self.n = n
        
    def reset(self):
        
        self.board = np.zeros([self.n, self.n])
        
        self.board[self.n//2-1, self.n//2] = self.board[self.n//2, self.n//2-1] = BLACK
        self.board[self.n//2-1, self.n//2-1] = self.board[self.n//2, self.n//2] = WHITE
        
        self.turn = WHITE
        self.get_valid_moves(self.turn)
        self.done = False
        
        return self.board
        
    def step(self, action):
        
        # Update the environment state based on the action chosen
        assert action in self.valid_moves, "Invalid move"
        self.board[action] = self.turn
        self.flip(action)
        self.get_valid_moves(-self.turn)
        
        # Calculate the reward for the new state
        score = self.score()
        self.done = (score is not None) and self.turn_passed
        self.turn_passed = score is not None
        self.reward = score if self.done else 0
        
        self.turn *= -1
        
        if self.turn_passed:
            self.turn *= -1
            self.get_valid_moves(self.turn)
            self.done = len(self.valid_moves) == 0
        
        return self.board, self.reward, self.done, {'turn': self.turn}
    
    def score(self):
        
        white, black, empty = self.do_count()
        
        if empty == 0:
            self.turn_passed = True
            return (white - black) / self.n**2

        if white == 0 or black == 0 or len(self.valid_moves) == 0:
            return (white - black) / self.n**2
        

        
        return None
    
    def get_valid_moves(self, color):
        
        places = []
        mat = np.where(self.board == color)
        positions = [(x,y) for x,y in zip(mat[0],mat[1])]
        for position in positions:
            for direction in range(1,9):
                p = self.get_direction_valid_moves(position, direction, color)
                if not p is None:
                    places.append(p)
                    
        places = list(set(places))
        self.valid_moves = places
        
        return places
    
    def get_direction_valid_moves(self, position, direction, color):
        
        row_inc, col_inc = direction2row[direction], direction2col[direction]
        x, y = position
        k = 1
        flat = []
        while (x+row_inc*k>=0) and (y+col_inc*k>=0) and (x+row_inc*k<self.n) and (y+col_inc*k<self.n):
            flat.append((self.board[x+row_inc*k, y+col_inc*k], (x+row_inc*k, y+col_inc*k)))
            k += 1
        
        for i, (x, ind) in enumerate(flat):
            if x == EMPTY:
                if i == 0:
                    return
                elif flat[i-1][0] == -color:
                    return ind
                else:
                    return
            elif x == -color:
                continue
            else:
                return
        
        
    def flip(self, position):
        
        for direction in range(1,9):
            self.direction_flip(position, direction)
            
    def direction_flip(self, position, direction):
        
        row_inc, col_inc = direction2row[direction], direction2col[direction]
        x, y = position
        k = 1
        flat = []
        while (x+row_inc*k>=0) and (y+col_inc*k>=0) and (x+row_inc*k<self.n) and (y+col_inc*k<self.n):
            flat.append((self.board[x+row_inc*k, y+col_inc*k], (x+row_inc*k, y+col_inc*k)))
            k += 1
        
        to_flip = []
        for i, (x, ind) in enumerate(flat):
            if x == self.turn:
                break
            elif x == -self.turn:
                to_flip.append(ind)
                if i == len(flat)-1:
                    return
            else:
                return
        
        for ind in to_flip:
            self.board[ind]*=-1
        
    def do_count(self):
        
        flat = self.board.reshape(-1)
        counts = Counter(flat)
        white, black, empty = counts[WHITE], counts[BLACK], counts[EMPTY]
        
        return white, black, empty
    
    def render(self):
        
        return '\n'.join([''.join([ASCII.getsymbol(value) for value in row]) for row in self.board])

# %%
env = OthelloEnv(n=8)
state = env.reset()
done = False
while not done:
    print(env.render())
    if env.turn_passed:
        print("------------------------------------PASSED TURN-------------------------------------------")
    print("valid moves: ",env.valid_moves)
    action = env.valid_moves[np.random.randint(len(env.valid_moves))]
    print("action: ",action)
    state, reward, done, info = env.step(action)
# Out:
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩⚪⚫🟩🟩🟩
# 🟩🟩🟩⚫⚪🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(4, 2), (2, 4), (5, 3), (3, 5)]
# action:  (2, 4)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩⚪🟩🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# 🟩🟩🟩⚫⚪🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(4, 5), (2, 5), (2, 3)]
# action:  (2, 3)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩⚫⚪🟩🟩🟩
# 🟩🟩🟩⚫⚪🟩🟩🟩
# 🟩🟩🟩⚫⚪🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(1, 2), (3, 2), (2, 2), (4, 2), (5, 2)]
# action:  (5, 2)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩⚫⚪🟩🟩🟩
# 🟩🟩🟩⚫⚪🟩🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# 🟩🟩⚪🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(5, 5), (4, 5), (1, 5), (5, 3), (2, 5), (3, 5)]
# action:  (5, 5)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩⚫⚪🟩🟩🟩
# 🟩🟩🟩⚫⚪🟩🟩🟩
# 🟩🟩🟩⚪⚫🟩🟩🟩
# 🟩🟩⚪🟩🟩⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(1, 2), (5, 4), (3, 2), (1, 3), (4, 5), (2, 2), (4, 2)]
# action:  (4, 2)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩⚫⚪🟩🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# 🟩🟩⚪⚪⚫🟩🟩🟩
# 🟩🟩⚪🟩🟩⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(4, 5), (1, 4), (2, 2), (2, 5), (4, 1), (5, 3)]
# action:  (1, 4)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩🟩🟩⚫⚫🟩🟩🟩
# 🟩🟩🟩⚪⚫🟩🟩🟩
# 🟩🟩⚪⚪⚫🟩🟩🟩
# 🟩🟩⚪🟩🟩⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(1, 3), (6, 6), (4, 5), (1, 5), (2, 5), (3, 5)]
# action:  (2, 5)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩🟩🟩⚫⚫⚪🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# 🟩🟩⚪⚪⚫🟩🟩🟩
# 🟩🟩⚪🟩🟩⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(2, 6), (4, 5), (3, 6), (2, 2), (5, 1), (4, 1), (5, 3)]
# action:  (2, 2)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩🟩⚫⚫⚫⚪🟩🟩
# 🟩🟩🟩⚫⚪🟩🟩🟩
# 🟩🟩⚪⚪⚫🟩🟩🟩
# 🟩🟩⚪🟩🟩⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(1, 2), (5, 4), (3, 2), (1, 3), (4, 5), (2, 1), (1, 5), (0, 4), (0, 3)]
# action:  (2, 1)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩⚪⚪⚪⚪⚪🟩🟩
# 🟩🟩🟩⚫⚪🟩🟩🟩
# 🟩🟩⚪⚪⚫🟩🟩🟩
# 🟩🟩⚪🟩🟩⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(3, 2), (1, 3), (1, 5), (3, 6), (5, 3), (5, 1), (4, 1), (1, 1), (3, 5)]
# action:  (3, 5)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩⚪⚪⚪⚪⚪🟩🟩
# 🟩🟩🟩⚫⚫⚫🟩🟩
# 🟩🟩⚪⚪⚫🟩🟩🟩
# 🟩🟩⚪🟩🟩⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(5, 4), (4, 6), (6, 6), (4, 5), (0, 5), (0, 4), (0, 3)]
# action:  (5, 4)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩⚪⚪⚪⚪⚪🟩🟩
# 🟩🟩🟩⚫⚪⚫🟩🟩
# 🟩🟩⚪⚪⚪🟩🟩🟩
# 🟩🟩⚪🟩⚪⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(6, 4), (3, 2), (1, 3), (1, 5), (3, 6), (5, 1), (1, 1), (5, 3)]
# action:  (5, 1)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩⚪⚪⚪⚪⚪🟩🟩
# 🟩🟩🟩⚫⚪⚫🟩🟩
# 🟩🟩⚫⚪⚪🟩🟩🟩
# 🟩⚫⚪🟩⚪⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(3, 2), (2, 6), (4, 6), (6, 6), (4, 5), (5, 6), (6, 0), (0, 5), (3, 6), (0, 4), (5, 0), (0, 3), (4, 1)]
# action:  (2, 6)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩⚪⚪⚪⚪⚪⚪🟩
# 🟩🟩🟩⚫⚪⚪🟩🟩
# 🟩🟩⚫⚪⚪🟩🟩🟩
# 🟩⚫⚪🟩⚪⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(6, 4), (3, 2), (1, 3), (4, 5), (1, 5), (6, 2), (3, 6), (1, 1), (5, 3)]
# action:  (1, 5)
# None False
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩⚫⚫🟩🟩
# 🟩⚪⚪⚪⚫⚪⚪🟩
# 🟩🟩🟩⚫⚪⚪🟩🟩
# 🟩🟩⚫⚪⚪🟩🟩🟩
# 🟩⚫⚪🟩⚪⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(3, 2), (1, 3), (6, 6), (5, 6), (0, 5), (5, 0), (0, 4), (0, 3), (4, 1)]
# action:  (0, 5)
# None False
# 🟩🟩🟩🟩🟩⚪🟩🟩
# 🟩🟩🟩🟩⚪⚪🟩🟩
# 🟩⚪⚪⚪⚫⚪⚪🟩
# 🟩🟩🟩⚫⚪⚪🟩🟩
# 🟩🟩⚫⚪⚪🟩🟩🟩
# 🟩⚫⚪🟩⚪⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(2, 7), (6, 4), (1, 3), (4, 6), (4, 5), (0, 6), (2, 0), (6, 2), (3, 6), (0, 4), (1, 1), (5, 3)]
# action:  (0, 4)
# None False
# 🟩🟩🟩🟩⚫⚪🟩🟩
# 🟩🟩🟩🟩⚫⚪🟩🟩
# 🟩⚪⚪⚪⚫⚪⚪🟩
# 🟩🟩🟩⚫⚪⚪🟩🟩
# 🟩🟩⚫⚪⚪🟩🟩🟩
# 🟩⚫⚪🟩⚪⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(3, 2), (1, 3), (6, 6), (5, 6), (6, 0), (5, 0), (0, 3), (4, 1)]
# action:  (4, 1)
# None False
# 🟩🟩🟩🟩⚫⚪🟩🟩
# 🟩🟩🟩🟩⚫⚪🟩🟩
# 🟩⚪⚪⚪⚫⚪⚪🟩
# 🟩🟩🟩⚫⚪⚪🟩🟩
# 🟩⚪⚪⚪⚪🟩🟩🟩
# 🟩⚫⚪🟩⚪⚫🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(2, 7), (6, 4), (3, 2), (1, 3), (4, 6), (3, 1), (0, 6), (2, 0), (1, 6), (3, 6), (3, 7), (1, 1), (5, 3)]
# action:  (6, 4)
# None False
# 🟩🟩🟩🟩⚫⚪🟩🟩
# 🟩🟩🟩🟩⚫⚪🟩🟩
# 🟩⚪⚪⚪⚫⚪⚪🟩
# 🟩🟩🟩⚫⚫⚪🟩🟩
# 🟩⚪⚪⚪⚫🟩🟩🟩
# 🟩⚫⚪🟩⚫⚫🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(3, 2), (1, 3), (6, 6), (4, 5), (6, 1), (6, 0), (5, 0), (0, 3), (6, 5), (5, 3)]
# action:  (1, 3)
# None False
# 🟩🟩🟩🟩⚫⚪🟩🟩
# 🟩🟩🟩⚪⚪⚪🟩🟩
# 🟩⚪⚪⚪⚪⚪⚪🟩
# 🟩🟩🟩⚫⚫⚪🟩🟩
# 🟩⚪⚪⚪⚫🟩🟩🟩
# 🟩⚫⚪🟩⚫⚫🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(1, 2), (3, 2), (6, 1), (3, 1), (4, 0), (0, 6), (1, 6), (3, 6), (1, 7), (3, 7), (0, 3), (1, 1), (5, 3)]
# action:  (3, 1)
# None False
# 🟩🟩🟩🟩⚫⚪🟩🟩
# 🟩🟩🟩⚫⚪⚪🟩🟩
# 🟩⚪⚫⚪⚪⚪⚪🟩
# 🟩⚫🟩⚫⚫⚪🟩🟩
# 🟩⚫⚪⚪⚫🟩🟩🟩
# 🟩⚫⚪🟩⚫⚫🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(1, 2), (3, 2), (4, 5), (3, 0), (6, 1), (4, 0), (6, 0), (7, 4), (2, 0), (5, 0), (0, 3), (0, 2), (6, 5), (5, 3)]
# action:  (0, 2)
# None False
# 🟩🟩⚪🟩⚫⚪🟩🟩
# 🟩🟩🟩⚪⚪⚪🟩🟩
# 🟩⚪⚫⚪⚪⚪⚪🟩
# 🟩⚫🟩⚫⚫⚪🟩🟩
# 🟩⚫⚪⚪⚫🟩🟩🟩
# 🟩⚫⚪🟩⚫⚫🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(2, 7), (1, 2), (3, 2), (6, 1), (6, 3), (0, 6), (2, 0), (1, 6), (3, 6), (1, 7), (3, 7), (0, 3), (1, 1), (5, 3)]
# action:  (5, 3)
# None False
# 🟩🟩⚪🟩⚫⚪🟩🟩
# 🟩🟩🟩⚪⚪⚪🟩🟩
# 🟩⚪⚫⚪⚪⚪⚪🟩
# 🟩⚫🟩⚫⚫⚪🟩🟩
# 🟩⚫⚫⚫⚫🟩🟩🟩
# 🟩⚫⚫⚫⚫⚫🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(3, 2), (4, 5), (6, 1), (6, 0), (6, 3), (7, 4), (6, 2), (0, 3), (4, 0)]
# action:  (4, 5)
# None False
# 🟩🟩⚪🟩⚫⚪🟩🟩
# 🟩🟩🟩⚪⚪⚪🟩🟩
# 🟩⚪⚫⚪⚪⚪⚪🟩
# 🟩⚫🟩⚫⚪⚪🟩🟩
# 🟩⚫⚫⚫⚫⚪🟩🟩
# 🟩⚫⚫⚫⚫⚫🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(2, 7), (4, 6), (0, 6), (2, 0), (1, 6), (3, 6), (1, 7), (3, 7), (0, 3), (1, 1)]
# action:  (0, 6)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩🟩🟩⚪⚪⚫🟩🟩
# 🟩⚪⚫⚪⚫⚪⚪🟩
# 🟩⚫🟩⚫⚪⚪🟩🟩
# 🟩⚫⚫⚫⚫⚪🟩🟩
# 🟩⚫⚫⚫⚫⚫🟩🟩
# 🟩🟩🟩🟩⚫🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(3, 2), (6, 1), (6, 3), (7, 4), (6, 2), (1, 6), (6, 5), (4, 0)]
# action:  (6, 2)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩🟩🟩⚪⚪⚫🟩🟩
# 🟩⚪⚫⚪⚫⚪⚪🟩
# 🟩⚫🟩⚫⚪⚪🟩🟩
# 🟩⚫⚫⚫⚪⚪🟩🟩
# 🟩⚫⚫⚪⚫⚫🟩🟩
# 🟩🟩⚪🟩⚫🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(1, 2), (2, 7), (3, 2), (7, 3), (4, 6), (6, 3), (2, 0), (1, 6), (3, 6), (3, 7), (0, 3), (1, 1), (7, 2)]
# action:  (6, 3)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩🟩🟩⚪⚪⚫🟩🟩
# 🟩⚪⚫⚪⚫⚪⚪🟩
# 🟩⚫🟩⚫⚪⚪🟩🟩
# 🟩⚫⚫⚫⚪⚪🟩🟩
# 🟩⚫⚫⚫⚫⚫🟩🟩
# 🟩🟩⚪⚫⚫🟩🟩🟩
# 🟩🟩🟩🟩🟩🟩🟩🟩
# valid moves:  [(7, 3), (3, 2), (6, 6), (6, 1), (7, 4), (1, 6), (7, 2), (1, 1), (6, 5), (4, 0)]
# action:  (7, 4)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩🟩🟩⚪⚪⚫🟩🟩
# 🟩⚪⚫⚪⚫⚪⚪🟩
# 🟩⚫🟩⚫⚪⚪🟩🟩
# 🟩⚫⚫⚫⚪⚪🟩🟩
# 🟩⚫⚫⚫⚪⚫🟩🟩
# 🟩🟩⚪⚫⚪🟩🟩🟩
# 🟩🟩🟩🟩⚪🟩🟩🟩
# valid moves:  [(1, 2), (2, 7), (3, 2), (7, 3), (4, 6), (7, 1), (6, 1), (2, 0), (7, 5), (1, 6), (3, 6), (1, 7), (3, 7), (0, 3), (7, 2), (1, 1), (6, 5)]
# action:  (1, 7)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩🟩🟩⚪⚪⚫🟩⚫
# 🟩⚪⚫⚪⚫⚪⚫🟩
# 🟩⚫🟩⚫⚪⚫🟩🟩
# 🟩⚫⚫⚫⚫⚪🟩🟩
# 🟩⚫⚫⚫⚪⚫🟩🟩
# 🟩🟩⚪⚫⚪🟩🟩🟩
# 🟩🟩🟩🟩⚪🟩🟩🟩
# valid moves:  [(2, 7), (7, 3), (3, 2), (4, 6), (5, 6), (3, 0), (6, 1), (2, 0), (1, 6), (3, 6), (5, 0), (7, 2), (6, 5), (4, 0)]
# action:  (7, 3)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩🟩🟩⚪⚪⚫🟩⚫
# 🟩⚪⚫⚪⚫⚪⚫🟩
# 🟩⚫🟩⚪⚪⚫🟩🟩
# 🟩⚫⚫⚪⚫⚪🟩🟩
# 🟩⚫⚫⚪⚪⚫🟩🟩
# 🟩🟩⚪⚪⚪🟩🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# valid moves:  [(1, 2), (3, 2), (4, 6), (7, 1), (2, 0), (7, 5), (1, 6), (1, 1), (7, 2)]
# action:  (2, 0)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩🟩🟩⚪⚪⚫🟩⚫
# ⚫⚫⚫⚪⚫⚪⚫🟩
# 🟩⚫🟩⚪⚪⚫🟩🟩
# 🟩⚫⚫⚪⚫⚪🟩🟩
# 🟩⚫⚫⚪⚪⚫🟩🟩
# 🟩🟩⚪⚪⚪🟩🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# valid moves:  [(2, 7), (3, 2), (4, 6), (6, 6), (5, 6), (3, 0), (6, 1), (6, 0), (1, 6), (3, 6), (5, 0), (1, 1), (6, 5), (4, 0)]
# action:  (6, 5)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩🟩🟩⚪⚪⚫🟩⚫
# ⚫⚫⚫⚪⚫⚪⚫🟩
# 🟩⚫🟩⚪⚪⚫🟩🟩
# 🟩⚫⚫⚪⚫⚪🟩🟩
# 🟩⚫⚫⚪⚪⚪🟩🟩
# 🟩🟩⚪⚪⚪⚪🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# valid moves:  [(1, 2), (3, 2), (4, 6), (6, 6), (7, 1), (5, 6), (7, 5), (1, 6), (7, 2)]
# action:  (4, 6)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩🟩🟩⚪⚪⚫🟩⚫
# ⚫⚫⚫⚪⚫⚪⚫🟩
# 🟩⚫🟩⚪⚪⚫🟩🟩
# 🟩⚫⚫⚪⚫⚫⚫🟩
# 🟩⚫⚫⚪⚪⚪🟩🟩
# 🟩🟩⚪⚪⚪⚪🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# valid moves:  [(2, 7), (4, 7), (3, 2), (5, 6), (3, 0), (6, 1), (5, 7), (6, 0), (1, 6), (3, 6), (5, 0), (3, 7), (1, 1), (4, 0)]
# action:  (4, 7)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩🟩🟩⚪⚪⚫🟩⚫
# ⚫⚫⚫⚪⚫⚪⚫🟩
# 🟩⚫🟩⚪⚪⚫🟩🟩
# 🟩⚫⚫⚪⚪⚪⚪⚪
# 🟩⚫⚫⚪⚪⚪🟩🟩
# 🟩🟩⚪⚪⚪⚪🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# valid moves:  [(1, 2), (3, 2), (6, 6), (7, 1), (5, 6), (5, 7), (7, 5), (1, 6), (7, 2)]
# action:  (1, 2)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩🟩⚫⚫⚫⚫🟩⚫
# ⚫⚫⚫⚪⚫⚪⚫🟩
# 🟩⚫🟩⚪⚪⚫🟩🟩
# 🟩⚫⚫⚪⚪⚪⚪⚪
# 🟩⚫⚫⚪⚪⚪🟩🟩
# 🟩🟩⚪⚪⚪⚪🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# valid moves:  [(0, 1), (2, 7), (3, 2), (3, 0), (6, 1), (6, 0), (3, 6), (5, 0), (0, 3), (1, 1), (4, 0)]
# action:  (1, 1)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩⚪⚫⚫⚫⚫🟩⚫
# ⚫⚫⚪⚪⚫⚪⚫🟩
# 🟩⚫🟩⚪⚪⚫🟩🟩
# 🟩⚫⚫⚪⚪⚪⚪⚪
# 🟩⚫⚫⚪⚪⚪🟩🟩
# 🟩🟩⚪⚪⚪⚪🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# valid moves:  [(0, 1), (3, 2), (7, 1), (5, 6), (5, 7), (7, 5), (1, 6), (3, 6), (1, 0), (7, 2)]
# action:  (3, 2)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩⚪⚫⚫⚫⚫🟩⚫
# ⚫⚫⚫⚫⚫⚪⚫🟩
# 🟩⚫⚫⚫⚫⚫🟩🟩
# 🟩⚫⚫⚪⚪⚪⚪⚪
# 🟩⚫⚫⚪⚪⚪🟩🟩
# 🟩🟩⚪⚪⚪⚪🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# valid moves:  [(2, 7), (0, 1), (3, 0), (1, 0), (6, 1), (1, 6), (5, 0), (0, 3), (4, 0)]
# action:  (4, 0)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# 🟩⚪⚫⚫⚫⚫🟩⚫
# ⚫⚫⚫⚫⚫⚪⚫🟩
# 🟩⚫⚫⚫⚫⚫🟩🟩
# ⚪⚪⚪⚪⚪⚪⚪⚪
# 🟩⚪⚫⚪⚪⚪🟩🟩
# 🟩🟩⚪⚪⚪⚪🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# valid moves:  [(0, 1), (0, 0), (6, 6), (5, 6), (7, 1), (6, 1), (7, 6), (5, 7), (6, 0), (3, 0), (7, 5), (1, 6), (3, 6), (5, 0), (1, 0), (7, 2)]
# action:  (1, 0)
# None False
# 🟩🟩⚪🟩⚫⚫⚫🟩
# ⚫⚫⚫⚫⚫⚫🟩⚫
# ⚫⚫⚫⚫⚫⚪⚫🟩
# 🟩⚫⚫⚫⚫⚫🟩🟩
# ⚪⚪⚪⚪⚪⚪⚪⚪
# 🟩⚪⚫⚪⚪⚪🟩🟩
# 🟩🟩⚪⚪⚪⚪🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# valid moves:  [(2, 7), (0, 1), (0, 0), (6, 1), (0, 3)]
# action:  (0, 0)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚫⚫⚫⚫🟩⚫
# ⚫⚫⚪⚫⚫⚪⚫🟩
# 🟩⚫⚫⚪⚫⚫🟩🟩
# ⚪⚪⚪⚪⚪⚪⚪⚪
# 🟩⚪⚫⚪⚪⚪🟩🟩
# 🟩🟩⚪⚪⚪⚪🟩🟩
# 🟩🟩🟩⚪⚪🟩🟩🟩
# valid moves:  [(0, 1), (7, 1), (5, 6), (3, 0), (6, 1), (7, 6), (5, 7), (6, 0), (7, 5), (1, 6), (3, 6), (5, 0), (7, 2)]
# action:  (7, 6)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚫⚫⚫⚫🟩⚫
# ⚫⚫⚪⚫⚫⚪⚫🟩
# 🟩⚫⚫⚪⚫⚫🟩🟩
# ⚪⚪⚪⚫⚪⚪⚪⚪
# 🟩⚪⚫⚪⚫⚪🟩🟩
# 🟩🟩⚪⚪⚪⚫🟩🟩
# 🟩🟩🟩⚪⚪🟩⚫🟩
# valid moves:  [(2, 7), (0, 1), (6, 6), (3, 0), (5, 6), (6, 1), (7, 5), (1, 6), (3, 6), (0, 3)]
# action:  (3, 6)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚫⚫⚫⚫🟩⚫
# ⚫⚫⚪⚫⚫⚪⚫🟩
# 🟩⚫⚫⚪⚪⚪⚪🟩
# ⚪⚪⚪⚫⚪⚪⚪⚪
# 🟩⚪⚫⚪⚫⚪🟩🟩
# 🟩🟩⚪⚪⚪⚫🟩🟩
# 🟩🟩🟩⚪⚪🟩⚫🟩
# valid moves:  [(0, 1), (2, 7), (7, 1), (5, 6), (3, 0), (6, 1), (5, 7), (6, 0), (7, 5), (1, 6), (5, 0), (3, 7), (7, 2)]
# action:  (3, 0)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚫⚫⚫⚫🟩⚫
# ⚫⚫⚪⚫⚫⚪⚫🟩
# ⚫⚫⚫⚪⚪⚪⚪🟩
# ⚪⚫⚪⚫⚪⚪⚪⚪
# 🟩⚪⚫⚪⚫⚪🟩🟩
# 🟩🟩⚪⚪⚪⚫🟩🟩
# 🟩🟩🟩⚪⚪🟩⚫🟩
# valid moves:  [(2, 7), (0, 1), (6, 6), (5, 6), (6, 1), (7, 5), (1, 6), (0, 3)]
# action:  (1, 6)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚪⚪⚫
# ⚫⚫⚪⚫⚫⚪⚪🟩
# ⚫⚫⚫⚪⚪⚪⚪🟩
# ⚪⚫⚪⚫⚪⚪⚪⚪
# 🟩⚪⚫⚪⚫⚪🟩🟩
# 🟩🟩⚪⚪⚪⚫🟩🟩
# 🟩🟩🟩⚪⚪🟩⚫🟩
# valid moves:  [(2, 7), (0, 1), (7, 1), (5, 6), (6, 1), (5, 7), (6, 0), (0, 7), (7, 5), (5, 0), (3, 7), (0, 3), (7, 2)]
# action:  (3, 7)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚫⚪⚫
# ⚫⚫⚪⚫⚫⚪⚫🟩
# ⚫⚫⚫⚫⚫⚫⚫⚫
# ⚪⚫⚪⚫⚪⚪⚪⚪
# 🟩⚪⚫⚪⚫⚪🟩🟩
# 🟩🟩⚪⚪⚪⚫🟩🟩
# 🟩🟩🟩⚪⚪🟩⚫🟩
# valid moves:  [(2, 7), (6, 6), (5, 6), (6, 1), (7, 5), (5, 0)]
# action:  (5, 0)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚫⚪⚫
# ⚫⚫⚪⚪⚫⚪⚫🟩
# ⚫⚫⚪⚫⚫⚫⚫⚫
# ⚪⚪⚪⚫⚪⚪⚪⚪
# ⚪⚪⚫⚪⚫⚪🟩🟩
# 🟩🟩⚪⚪⚪⚫🟩🟩
# 🟩🟩🟩⚪⚪🟩⚫🟩
# valid moves:  [(2, 7), (0, 1), (6, 6), (5, 6), (7, 1), (6, 1), (5, 7), (6, 0), (0, 7), (7, 5), (0, 3), (7, 2)]
# action:  (7, 1)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚫⚪⚫
# ⚫⚫⚪⚪⚫⚪⚫🟩
# ⚫⚫⚪⚫⚫⚫⚫⚫
# ⚪⚪⚪⚫⚫⚪⚪⚪
# ⚪⚪⚫⚫⚫⚪🟩🟩
# 🟩🟩⚫⚪⚪⚫🟩🟩
# 🟩⚫🟩⚪⚪🟩⚫🟩
# valid moves:  [(2, 7), (6, 6), (5, 6), (6, 1), (7, 5), (7, 2)]
# action:  (7, 5)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚫⚪⚫
# ⚫⚫⚪⚪⚫⚪⚫🟩
# ⚫⚫⚪⚫⚫⚫⚫⚫
# ⚪⚪⚪⚫⚫⚪⚪⚪
# ⚪⚪⚫⚫⚫⚪🟩🟩
# 🟩🟩⚫⚪⚪⚪🟩🟩
# 🟩⚫🟩⚪⚪⚪⚫🟩
# valid moves:  [(2, 7), (0, 1), (6, 6), (5, 6), (6, 1), (5, 7), (6, 0), (0, 7), (0, 3), (7, 2)]
# action:  (6, 1)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚫⚪⚫
# ⚫⚫⚪⚪⚫⚪⚫🟩
# ⚫⚫⚪⚫⚫⚫⚫⚫
# ⚪⚫⚪⚫⚫⚪⚪⚪
# ⚪⚫⚫⚫⚫⚪🟩🟩
# 🟩⚫⚫⚪⚪⚪🟩🟩
# 🟩⚫🟩⚪⚪⚪⚫🟩
# valid moves:  [(2, 7), (7, 0), (6, 0), (7, 7), (7, 2)]
# action:  (7, 0)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚫⚪⚫
# ⚫⚫⚪⚪⚫⚪⚫🟩
# ⚫⚫⚪⚫⚪⚫⚫⚫
# ⚪⚫⚪⚪⚫⚪⚪⚪
# ⚪⚫⚪⚫⚫⚪🟩🟩
# 🟩⚪⚫⚪⚪⚪🟩🟩
# ⚪⚫🟩⚪⚪⚪⚫🟩
# valid moves:  [(2, 7), (0, 1), (6, 6), (5, 6), (5, 7), (6, 0), (0, 3), (7, 2)]
# action:  (2, 7)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚫⚫⚫
# ⚫⚫⚪⚪⚫⚪⚫⚫
# ⚫⚫⚪⚫⚪⚫⚫⚫
# ⚪⚫⚪⚪⚫⚪⚪⚪
# ⚪⚫⚪⚫⚫⚪🟩🟩
# 🟩⚪⚫⚪⚪⚪🟩🟩
# ⚪⚫🟩⚪⚪⚪⚫🟩
# valid moves:  [(7, 7), (7, 2), (6, 0), (0, 7)]
# action:  (7, 7)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚫⚫⚫
# ⚫⚫⚪⚪⚫⚪⚫⚫
# ⚫⚫⚪⚫⚪⚫⚫⚫
# ⚪⚫⚪⚪⚫⚪⚪⚪
# ⚪⚫⚪⚫⚫⚪🟩🟩
# 🟩⚪⚫⚪⚪⚪🟩🟩
# ⚪⚫🟩⚪⚪⚪⚪⚪
# valid moves:  [(0, 1), (6, 6), (5, 6), (5, 7), (6, 0), (0, 3), (7, 2)]
# action:  (6, 6)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚫⚫⚫
# ⚫⚫⚪⚪⚫⚪⚫⚫
# ⚫⚫⚪⚫⚪⚫⚫⚫
# ⚪⚫⚪⚪⚫⚪⚪⚪
# ⚪⚫⚪⚫⚫⚫🟩🟩
# 🟩⚪⚫⚫⚫⚫⚫🟩
# ⚪⚫🟩⚪⚪⚪⚪⚪
# valid moves:  [(6, 7), (5, 6), (5, 7), (6, 0), (0, 7), (7, 2)]
# action:  (5, 6)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚫⚫⚫
# ⚫⚫⚪⚪⚫⚪⚫⚫
# ⚫⚫⚪⚫⚪⚫⚫⚫
# ⚪⚫⚪⚪⚫⚪⚪⚪
# ⚪⚫⚪⚪⚪⚪⚪🟩
# 🟩⚪⚫⚫⚫⚪⚪🟩
# ⚪⚫🟩⚪⚪⚪⚪⚪
# valid moves:  [(0, 1), (6, 7), (5, 7), (6, 0), (0, 3)]
# action:  (6, 7)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚫⚫⚫
# ⚫⚫⚪⚪⚫⚪⚫⚫
# ⚫⚫⚪⚫⚪⚫⚫⚫
# ⚪⚫⚪⚪⚫⚪⚪⚪
# ⚪⚫⚪⚪⚪⚪⚪🟩
# 🟩⚪⚫⚫⚫⚫⚫⚫
# ⚪⚫🟩⚪⚪⚪⚪⚪
# valid moves:  [(7, 2), (6, 0), (0, 7), (5, 7)]
# action:  (5, 7)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚫⚫⚫
# ⚫⚫⚪⚪⚫⚪⚫⚫
# ⚫⚫⚪⚫⚪⚫⚫⚫
# ⚪⚫⚪⚪⚫⚪⚪⚪
# ⚪⚫⚪⚪⚪⚪⚪⚪
# 🟩⚪⚫⚫⚫⚫⚪⚪
# ⚪⚫🟩⚪⚪⚪⚪⚪
# valid moves:  [(0, 1), (0, 3), (6, 0)]
# action:  (6, 0)
# None False
# ⚪🟩⚪🟩⚫⚫⚫🟩
# ⚫⚪⚪⚪⚪⚫⚫⚫
# ⚫⚫⚪⚪⚫⚪⚫⚫
# ⚫⚫⚪⚫⚪⚫⚫⚫
# ⚫⚫⚪⚪⚫⚪⚪⚪
# ⚫⚫⚪⚪⚪⚪⚪⚪
# ⚫⚫⚫⚫⚫⚫⚪⚪
# ⚪⚫🟩⚪⚪⚪⚪⚪
# valid moves:  [(7, 2), (0, 7)]
# action:  (0, 7)
# None False
# ⚪🟩⚪🟩⚫⚫⚫⚪
# ⚫⚪⚪⚪⚪⚫⚪⚪
# ⚫⚫⚪⚪⚫⚪⚫⚪
# ⚫⚫⚪⚫⚪⚫⚫⚪
# ⚫⚫⚪⚪⚫⚪⚪⚪
# ⚫⚫⚪⚪⚪⚪⚪⚪
# ⚫⚫⚫⚫⚫⚫⚪⚪
# ⚪⚫🟩⚪⚪⚪⚪⚪
# valid moves:  [(0, 1), (0, 3)]
# action:  (0, 3)
# None False
# ⚪🟩⚪⚫⚫⚫⚫⚪
# ⚫⚪⚫⚫⚫⚫⚪⚪
# ⚫⚫⚪⚫⚫⚫⚫⚪
# ⚫⚫⚪⚫⚪⚫⚫⚪
# ⚫⚫⚪⚪⚫⚪⚪⚪
# ⚫⚫⚪⚪⚪⚪⚪⚪
# ⚫⚫⚫⚫⚫⚫⚪⚪
# ⚪⚫🟩⚪⚪⚪⚪⚪
# valid moves:  [(0, 1), (7, 2)]
# action:  (0, 1)
# 0.046875 False
# ⚪⚪⚪⚫⚫⚫⚫⚪
# ⚫⚪⚪⚫⚫⚫⚪⚪
# ⚫⚫⚪⚪⚫⚫⚫⚪
# ⚫⚫⚪⚫⚪⚫⚫⚪
# ⚫⚫⚪⚪⚫⚪⚪⚪
# ⚫⚫⚪⚪⚪⚪⚪⚪
# ⚫⚫⚫⚫⚫⚫⚪⚪
# ⚪⚫🟩⚪⚪⚪⚪⚪
# ------------------------------------PASSED TURN-------------------------------------------
# valid moves:  [(7, 2)]
# action:  (7, 2)
# 0.15625 True

# %%
print("FINAL BOARD: \n{}\n\nTURN: {}\nFINAL SCORE: {} ".format(env.render(), info['turn'], reward))
# Out:
# FINAL BOARD:
# ⚪⚪⚪⚫⚫⚫⚫⚪
# ⚫⚪⚪⚫⚫⚫⚪⚪
# ⚫⚫⚪⚪⚫⚫⚫⚪
# ⚫⚫⚪⚫⚪⚫⚫⚪
# ⚫⚫⚪⚪⚫⚪⚪⚪
# ⚫⚫⚪⚪⚪⚪⚪⚪
# ⚫⚫⚪⚪⚫⚫⚪⚪
# ⚪⚪⚪⚪⚪⚪⚪⚪
#
# TURN: 1
# FINAL SCORE: 0.15625
